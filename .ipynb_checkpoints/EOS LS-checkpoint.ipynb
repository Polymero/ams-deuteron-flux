# %% [markdown]
# # EOS LS

# %%
import matplotlib.pyplot as plt

# %%
with open('eosls.txt','r') as f:
    data = f.read()
    f.close()

# %%
[int(i.replace('.root','')) for i in data.split('\n') if '.root' in i]
# Out:
# [1305853512,
#  1305855335,
#  1305857186,
#  1305859009,
#  1305860862,
#  1305862686,
#  1305864537,
#  1305867269,
#  1305869092,
#  1305870945,
#  1305873136,
#  1305874960,
#  1305876813,
#  1305878637,
#  1305880488,
#  1305882311,
#  1305884164,
#  1305885200,
#  1305887023,
#  1305888875,
#  1305890698,
#  1305892551,
#  1305894374,
#  1305898050,
#  1305899902,
#  1305901725,
#  1305903577,
#  1305905400,
#  1305907255,
#  1305909402,
#  1305910682,
#  1305911458,
#  1305912827,
#  1305913683,
#  1305916438,
#  1305917243,
#  1305918748,
#  1305921904,
#  1305922845,
#  1305924022,
#  1305925072,
#  1305928763,
#  1305929750,
#  1305930587,
#  1305934329,
#  1305934852,
#  1305935488,
#  1305936074,
#  1305937356,
#  1305939911,
#  1305940417,
#  1305940918,
#  1305941227,
#  1305943170,
#  1305944557,
#  1305945754,
#  1305946389,
#  1305946907,
#  1305948125,
#  1305949353,
#  1305951772,
#  1305952442,
#  1305953892,
#  1305955357,
#  1305957329,
#  1305959153,
# ...
